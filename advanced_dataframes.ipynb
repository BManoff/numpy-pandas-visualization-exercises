# %% [markdown]
# PART I

# %%
import pandas as pd
import numpy as np
from pydataset import data
from env import host, user, password

# %%
def get_db_url(dbname, username = user, hostname = host, password = password): 
    url = f'mysql+pymysql://{user}:{password}@{host}/{dbname}'
    return url

# %%
get_db_url('employees', username = user, hostname = host, password = password)
# Out:
# 'mysql+pymysql://kalpana_1815:tiyaKj87BIWm6Ge9Mi86IqxkemToFu1b@157.230.209.171/employees'

# %%
#Once you have successfully run a query:
# a. Intentionally make a typo in the database url. What kind of error message do you see?

get_db_url(emplo, username = user, hostname = host, password = password)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/brian/codeup-data-science/numpy-pandas-visualization-exercises/advanced_dataframes.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/brian/codeup-data-science/numpy-pandas-visualization-exercises/advanced_dataframes.ipynb#ch0000003?line=0'>1</a> get_db_url(emplo, username = user, hostname = host, password = password)
#
# NameError: name 'emplo' is not defined

# %%
# b. Intentionally make an error in your SQL query. What does the error message look like?

sql = '''
SELECT
    emp_no,
    first_name,
    last_name
FROM employees
WHERE gender = 'F'
LIMIT 100
'''

employees = pd.read_sql(sql, get_db_url('employees', username = user, hostname = host, password = password))
employees.head()
# Out:
#    emp_no first_name  last_name
# 0   10002    Bezalel     Simmel
# 1   10006     Anneke    Preusig
# 2   10007    Tzvetan  Zielinski
# 3   10009     Sumant       Peac
# 4   10010  Duangkaew   Piveteau

# %%
# Read the employees and titles tables into two separate DataFrames.

sql1 = '''
SELECT
    *
FROM employees
LIMIT 100
'''

employees = pd.read_sql(sql1, get_db_url('employees', username = user, hostname = host, password = password))
employees.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
# Read the employees and titles tables into two separate DataFrames.
sql2 = '''
SELECT
   *
FROM titles
limit 100
'''

titles = pd.read_sql(sql2, get_db_url('employees', username = user, hostname = host, password = password))
titles.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
print(employees.shape)
print(titles.shape)
# Out:
# (100, 6)
# (100, 4)

# %%
print(employees.info())
print(employees.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_no      100 non-null    int64
#  1   birth_date  100 non-null    object
#  2   first_name  100 non-null    object
#  3   last_name   100 non-null    object
#  4   gender      100 non-null    object
#  5   hire_date   100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB
# None
#              emp_no
# count    100.000000
# mean   10050.500000
# std       29.011492
# min    10001.000000
# 25%    10025.750000
# 50%    10050.500000
# 75%    10075.250000
# max    10100.000000

# %%
print(titles.info())
print(titles.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   emp_no     100 non-null    int64
#  1   title      100 non-null    object
#  2   from_date  100 non-null    object
#  3   to_date    100 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.2+ KB
# None
#              emp_no
# count    100.000000
# mean   10034.320000
# std       18.656859
# min    10001.000000
# 25%    10018.000000
# 50%    10035.500000
# 75%    10050.000000
# max    10066.000000

# %%
len(titles.title.unique())
# Out:
# 6

# %%
titles.to_date.sort_values(ascending=False).head(1)
# Out:
# 0    9999-01-01
# Name: to_date, dtype: object

# %%
titles.to_date.sort_values().head(1)
# Out:
# 71    1987-01-27
# Name: to_date, dtype: object

# %%
titles.to_date.sort_values().tail(1)
# Out:
# 49    9999-01-01
# Name: to_date, dtype: object

# %% [markdown]
# PART II

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
users.merge(roles, left_on='role_id', right_on='id', left_index=False, right_index=False, indicator=False, how='right')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %%
users.merge(roles, left_on='role_id', right_on='id', left_index=False, right_index=False, indicator=False, how='outer')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %%
(users.merge(roles, 
            left_on='role_id', 
            right_on='id', 
            how='inner')
    .drop(columns=['role_id', 'id_x', 'id_y'])
    #.drop(columns='id')
            
)
# Out:
#   name_x    name_y
# 0    bob     admin
# 1    joe    author
# 2  sally  reviewer
# 3   adam  reviewer

# %%
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
#print(mpg.info())
#print(mpg.describe())
print(data('mpg', show_doc = True))
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.
#
#
# None

# %%
#234 rows × 11 columns
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg = mpg.rename(columns={'cyl': 'cylinder', 
                     'displ': 'displacement',
                     'trans': 'transmission',
                     'drv': 'drive_type',
                     'cty': 'city',
                     'hwy': 'highway',
                     'fl': 'fuel',
                     }
            )
mpg
# Out:
#     manufacturer   model  displacement  year  cylinder transmission  \
# 1           audi      a4           1.8  1999         4     auto(l5)
# 2           audi      a4           1.8  1999         4   manual(m5)
# 3           audi      a4           2.0  2008         4   manual(m6)
# 4           audi      a4           2.0  2008         4     auto(av)
# 5           audi      a4           2.8  1999         6     auto(l5)
# ..           ...     ...           ...   ...       ...          ...
# 230   volkswagen  passat           2.0  2008         4     auto(s6)
# 231   volkswagen  passat           2.0  2008         4   manual(m6)
# 232   volkswagen  passat           2.8  1999         6     auto(l5)
# 233   volkswagen  passat           2.8  1999         6   manual(m5)
# 234   volkswagen  passat           3.6  2008         6     auto(s6)
#
#     drive_type  city  highway fluid    class  mileage_difference
# 1            f    18       29     p  compact                  11
# ...

# %%
print(mpg.describe())
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.
#
#
# None

# %%
len(mpg.manufacturer.unique())
# Out:
# 15

# %%
len(mpg.model.unique())
# Out:
# 38

# %%
mpg['mileage_difference'] = mpg.highway - mpg.city
mpg
# Out:
#     manufacturer   model  displ  year  cylinder transmission drive_type  city  \
# 1           audi      a4    1.8  1999         4     auto(l5)          f    18
# 2           audi      a4    1.8  1999         4   manual(m5)          f    21
# 3           audi      a4    2.0  2008         4   manual(m6)          f    20
# 4           audi      a4    2.0  2008         4     auto(av)          f    21
# 5           audi      a4    2.8  1999         6     auto(l5)          f    16
# ..           ...     ...    ...   ...       ...          ...        ...   ...
# 230   volkswagen  passat    2.0  2008         4     auto(s6)          f    19
# 231   volkswagen  passat    2.0  2008         4   manual(m6)          f    21
# 232   volkswagen  passat    2.8  1999         6     auto(l5)          f    16
# 233   volkswagen  passat    2.8  1999         6   manual(m5)          f    18
# 234   volkswagen  passat    3.6  2008         6     auto(s6)          f    17
#
# ...

# %%
mpg['average_mileage'] = (mpg.city + mpg.highway)/2
mpg
# Out:
#     manufacturer   model  displacement  year  cylinder transmission  \
# 1           audi      a4           1.8  1999         4     auto(l5)
# 2           audi      a4           1.8  1999         4   manual(m5)
# 3           audi      a4           2.0  2008         4   manual(m6)
# 4           audi      a4           2.0  2008         4     auto(av)
# 5           audi      a4           2.8  1999         6     auto(l5)
# ..           ...     ...           ...   ...       ...          ...
# 230   volkswagen  passat           2.0  2008         4     auto(s6)
# 231   volkswagen  passat           2.0  2008         4   manual(m6)
# 232   volkswagen  passat           2.8  1999         6     auto(l5)
# 233   volkswagen  passat           2.8  1999         6   manual(m5)
# 234   volkswagen  passat           3.6  2008         6     auto(s6)
#
#     drive_type  city  highway fluid    class  mileage_difference  \
# 1            f    18       29     p  compact                  11
# ...

# %%
mpg['is_automatic'] = mpg.transmission.str.startswith('a')
mpg
# Out:
#     manufacturer   model  displacement  year  cylinder transmission  \
# 1           audi      a4           1.8  1999         4     auto(l5)
# 2           audi      a4           1.8  1999         4   manual(m5)
# 3           audi      a4           2.0  2008         4   manual(m6)
# 4           audi      a4           2.0  2008         4     auto(av)
# 5           audi      a4           2.8  1999         6     auto(l5)
# ..           ...     ...           ...   ...       ...          ...
# 230   volkswagen  passat           2.0  2008         4     auto(s6)
# 231   volkswagen  passat           2.0  2008         4   manual(m6)
# 232   volkswagen  passat           2.8  1999         6     auto(l5)
# 233   volkswagen  passat           2.8  1999         6   manual(m5)
# 234   volkswagen  passat           3.6  2008         6     auto(s6)
#
#     drive_type  city  highway fluid    class  mileage_difference  \
# 1            f    18       29     p  compact                  11
# ...

# %%
mpg.groupby('manufacturer').average_mileage.mean().nlargest(n=1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %%
#mpg.groupby('is_automatic').average_mileage.agg(['mean', 'max']).head(1) # <--- working solution but sloppy/indirect

mpg['drive_avg'] = np.where(mpg.is_automatic == True, 'auto', 'manual')
mpg.groupby('drive_avg').average_mileage.mean() # <--- better solution
# Out:
# drive_avg
# auto      19.130573
# manual    22.227273
# Name: average_mileage, dtype: float64
